# %% [markdown]
# # 07 Evaluation And Visualization
#
# Summarize final metrics, plots, and error analysis for the capstone report.

# %%
  from google.colab import drive
  drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
  # %cd /content/drive/MyDrive/final_project
# Out:
# /content/drive/MyDrive/final_project

# %%
ls
# Out:
# artifacts/  notebooks/      reports/          SUPERVISOR_NOTES_REPORT.md
# data/       pyproject.toml  requirements.txt  tests/
# docs/       README.md       src/

# %%
  # !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 648.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
  # !python -m src.cli prepare
# Out:
# 2026-04-26 18:39:29,722 | INFO | src.data.preprocess | Reading yellow_tripdata_2024-01.parquet
# 2026-04-26 18:39:35,855 | INFO | src.data.preprocess | Reading yellow_tripdata_2024-02.parquet
# 2026-04-26 18:39:43,479 | INFO | src.data.preprocess | Reading yellow_tripdata_2024-03.parquet
# 2026-04-26 18:39:48,733 | INFO | src.data.preprocess | Loaded 900000 rows from 3 file(s)
# 2026-04-26 18:41:00,645 | INFO | __main__ | Prepared feature dataset with 485615 rows

# %%
  # %cd /content/drive/MyDrive/final_project

  If you uploaded a zip instead:

  # !unzip final_project.zip -d /content/
  # %cd /content/final_project

  2. Install Dependencies
  Try:

  # !pip install -r requirements.txt

  If Colab has issues with the pinned Torch version, use this fallback:

  # !grep -v "^torch==" requirements.txt > /tmp/requirements_colab.txt
  # !pip install -r /tmp/requirements_colab.txt

  Then restart runtime if Colab asks.

  3. Run The Pipeline
  If raw data is already inside the project, start from prepare:

  # !python -m src.cli prepare
  # !python -m src.cli train
  # !python -m src.cli evaluate

  If you need to download NYC TLC data first:

  # !python -m src.cli ingest --start-month 2024-01 --end-month 2024-03
  # !python -m src.cli prepare
  # !python -m src.cli train
  # !python -m src.cli evaluate

  Training may take a long time. Use GPU runtime if possible:

  Runtime > Change runtime type > GPU

  4. Run Tests

  # !python -m pytest -q -p no:cacheprovider

  5. Run Streamlit Dashboard In Colab
  Start Streamlit:

  # !streamlit run src/app/dashboard.py --server.port 8501 --server.headless true &

  Then generate a Colab proxy link:

  from google.colab import output
  output.eval_js("google.colab.kernel.proxyPort(8501)")

  Open the printed/proxy URL.

  Recommended Colab Order

  # %cd /content/drive/MyDrive/final_project
  # !pip install -r requirements.txt
  # !python -m src.cli prepare
  # !python -m src.cli train
  # !python -m src.cli evaluate
  # !streamlit run src/app/dashboard.py --server.port 8501 --server.headless true &

  Then:

  from google.colab import output
  output.eval_js("google.colab.kernel.proxyPort(8501)")

  Make sure these files exist before opening the dashboard:

  # !ls artifacts/metadata/training_manifest.json
  # !ls data/processed/final_merged_dataset.parquet
  # !ls artifacts/metadata/event_integration_summary.json


› Use /skills to list available skills
